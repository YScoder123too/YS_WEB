# %%
import pandas as pd
import numpy as np

# %%
dogs = pd.read_csv("pets.csv")
dogs
# Out:
#       Name      Breed          Color  Height  Weight Date of Birth
# 0    Bella   Labrador          Brown    56.0    25.0    07-01-2013
# 1  Charlie     Poodle          Black     NaN    23.0     9/16/2016
# 2     Lucy       Chow     Chow Brown    46.0    22.0     8/25/2014
# 3   Cooper  Schnauzer           Gray    49.0     NaN    12-11-2011
# 4      Max   Labrador          Black    56.0    29.0     1/20/2017
# 5   Stella  Chihuahua            Tan    18.0     2.0     4/20/2015
# 6   Bernie        St.  Bernard White    77.0    74.0     2/27/2018

# %% [markdown]
# # Index and Columns

# %%
dogs.columns
# Out:
# Index(['Name', 'Breed', 'Color', 'Height', 'Weight', 'Date of Birth'], dtype='object')

# %%
dogs.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
pet_index=dogs.set_index('Name')
print(pet_index)
# Out:
#              Breed          Color  Height  Weight Date of Birth
# Name
# Bella     Labrador          Brown    56.0    25.0    07-01-2013
# Charlie     Poodle          Black     NaN    23.0     9/16/2016
# Lucy          Chow     Chow Brown    46.0    22.0     8/25/2014
# Cooper   Schnauzer           Gray    49.0     NaN    12-11-2011
# Max       Labrador          Black    56.0    29.0     1/20/2017
# Stella   Chihuahua            Tan    18.0     2.0     4/20/2015
# Bernie         St.  Bernard White    77.0    74.0     2/27/2018

# %%
pet_index.reset_index()
# Out:
#       Name      Breed          Color  Height  Weight Date of Birth
# 0    Bella   Labrador          Brown    56.0    25.0    07-01-2013
# 1  Charlie     Poodle          Black     NaN    23.0     9/16/2016
# 2     Lucy       Chow     Chow Brown    46.0    22.0     8/25/2014
# 3   Cooper  Schnauzer           Gray    49.0     NaN    12-11-2011
# 4      Max   Labrador          Black    56.0    29.0     1/20/2017
# 5   Stella  Chihuahua            Tan    18.0     2.0     4/20/2015
# 6   Bernie        St.  Bernard White    77.0    74.0     2/27/2018

# %%
#dogs.reset_index(drop=True)

# %%
dogs[df['Name'].isin(['Bella','Lucy','Stella'])]'''IMPORTANT'''
# Out:
#      Name      Breed       Color  Height  Weight Date of Birth
# 0   Bella   Labrador       Brown    56.0    25.0    07-01-2013
# 2    Lucy       Chow  Chow Brown    46.0    22.0     8/25/2014
# 5  Stella  Chihuahua         Tan    18.0     2.0     4/20/2015

# %%
dogs[df['Color'].isin(['Brown','Black'])]
# Out:
#       Name     Breed  Color  Height  Weight Date of Birth
# 0    Bella  Labrador  Brown    56.0    25.0    07-01-2013
# 1  Charlie    Poodle  Black     NaN    23.0     9/16/2016
# 4      Max  Labrador  Black    56.0    29.0     1/20/2017

# %%
dogs[df['Weight']>25]
# Out:
#      Name     Breed          Color  Height  Weight Date of Birth
# 4     Max  Labrador          Black    56.0    29.0     1/20/2017
# 6  Bernie       St.  Bernard White    77.0    74.0     2/27/2018

# %% [markdown]
# loc

# %%
dogs.loc[:,['Breed']]#[rows:columns]
'''IMPORTANT'''
# Out:
#        Breed
# 0   Labrador
# 1     Poodle
# 2       Chow
# 3  Schnauzer
# 4   Labrador
# 5  Chihuahua
# 6        St.

# %%
dogs.loc[:,['Breed','Color','Weight']]
# Out:
#        Breed          Color  Weight
# 0   Labrador          Brown    25.0
# 1     Poodle          Black    23.0
# 2       Chow     Chow Brown    22.0
# 3  Schnauzer           Gray     NaN
# 4   Labrador          Black    29.0
# 5  Chihuahua            Tan     2.0
# 6        St.  Bernard White    74.0

# %% [markdown]
# iloc

# %%
dogs.iloc[:,0:3]#[rows:column 0,1,2]
# Out:
#       Name      Breed          Color
# 0    Bella   Labrador          Brown
# 1  Charlie     Poodle          Black
# 2     Lucy       Chow     Chow Brown
# 3   Cooper  Schnauzer           Gray
# 4      Max   Labrador          Black
# 5   Stella  Chihuahua            Tan
# 6   Bernie        St.  Bernard White

# %%
dogs.iloc[:,2:]#[rows:column from color to ahead]
# Out:
#            Color  Height  Weight Date of Birth
# 0          Brown    56.0    25.0    07-01-2013
# 1          Black     NaN    23.0     9/16/2016
# 2     Chow Brown    46.0    22.0     8/25/2014
# 3           Gray    49.0     NaN    12-11-2011
# 4          Black    56.0    29.0     1/20/2017
# 5            Tan    18.0     2.0     4/20/2015
# 6  Bernard White    77.0    74.0     2/27/2018

# %%
dogs.iloc[0:3,2:]
# Out:
#         Color  Height  Weight Date of Birth
# 0       Brown    56.0    25.0    07-01-2013
# 1       Black     NaN    23.0     9/16/2016
# 2  Chow Brown    46.0    22.0     8/25/2014
