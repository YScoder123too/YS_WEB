# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv("bank_marketing.csv")
a.head()
# Out:
#    client_id  age        job  marital    education credit_default mortgage  \
# 0          0   56  housemaid  married     basic.4y             no       no
# 1          1   57   services  married  high.school        unknown       no
# 2          2   37   services  married  high.school             no      yes
# 3          3   40     admin.  married     basic.6y             no       no
# 4          4   56   services  married  high.school             no       no
#
#   month  day  contact_duration  number_contacts  previous_campaign_contacts  \
# 0   may   13               261                1                           0
# 1   may   19               149                1                           0
# 2   may   23               226                1                           0
# 3   may   27               151                1                           0
# 4   may    3               307                1                           0
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   client_id                   41188 non-null  int64
#  1   age                         41188 non-null  int64
#  2   job                         41188 non-null  object
#  3   marital                     41188 non-null  object
#  4   education                   41188 non-null  object
#  5   credit_default              41188 non-null  object
#  6   mortgage                    41188 non-null  object
#  7   month                       41188 non-null  object
#  8   day                         41188 non-null  int64
#  9   contact_duration            41188 non-null  int64
#  10  number_contacts             41188 non-null  int64
#  11  previous_campaign_contacts  41188 non-null  int64
#  12  previous_outcome            41188 non-null  object
# ...

# %%
b=a[['client_id','age','job','marital','education','credit_default','mortgage']]
b.head()
# Out:
#    client_id  age        job  marital    education credit_default mortgage
# 0          0   56  housemaid  married     basic.4y             no       no
# 1          1   57   services  married  high.school        unknown       no
# 2          2   37   services  married  high.school             no      yes
# 3          3   40     admin.  married     basic.6y             no       no
# 4          4   56   services  married  high.school             no       no

# %%
'''iloc'''
c=a.iloc[:,0:8]
c.head()#yaha index se deal karna hai ok bruh?...loc mai name se deal karna tha..range mai iloc mast kaam karega..sequence is required
# Out:
#    client_id  age        job  marital    education credit_default mortgage  \
# 0          0   56  housemaid  married     basic.4y             no       no
# 1          1   57   services  married  high.school        unknown       no
# 2          2   37   services  married  high.school             no      yes
# 3          3   40     admin.  married     basic.6y             no       no
# 4          4   56   services  married  high.school             no       no
#
#   month
# 0   may
# 1   may
# 2   may
# 3   may
# 4   may

# %%
c['job']=c['job'].str.replace('.','_')#'''MAST'''

# %%
print(c['job'])
# Out:
# 0          housemaid
# 1           services
# 2           services
# 3             admin_
# 4           services
#             ...
# 41183        retired
# 41184    blue-collar
# 41185        retired
# 41186     technician
# 41187        retired
# Name: job, Length: 41188, dtype: object

# %%
c['education']=c['education'].str.replace('.','_')

# %%
print(c['education'])
# Out:
# 0                   basic_4y
# 1                high_school
# 2                high_school
# 3                   basic_6y
# 4                high_school
#                 ...
# 41183    professional_course
# 41184    professional_course
# 41185      university_degree
# 41186    professional_course
# 41187    professional_course
# Name: education, Length: 41188, dtype: object

# %%
c['education'].value_counts()
# Out:
# education
# university_degree      12168
# high_school             9515
# basic_9y                6045
# professional_course     5243
# basic_4y                4176
# basic_6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
c['education']=c['education'].replace('unknown',np.NAN)#'''MAST'''

# %%
print(c['education'])
# Out:
# 0                   basic_4y
# 1                high_school
# 2                high_school
# 3                   basic_6y
# 4                high_school
#                 ...
# 41183    professional_course
# 41184    professional_course
# 41185      university_degree
# 41186    professional_course
# 41187    professional_course
# Name: education, Length: 41188, dtype: object

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   client_id                   41188 non-null  int64
#  1   age                         41188 non-null  int64
#  2   job                         41188 non-null  object
#  3   marital                     41188 non-null  object
#  4   education                   41188 non-null  object
#  5   credit_default              41188 non-null  object
#  6   mortgage                    41188 non-null  object
#  7   month                       41188 non-null  object
#  8   day                         41188 non-null  int64
#  9   contact_duration            41188 non-null  int64
#  10  number_contacts             41188 non-null  int64
#  11  previous_campaign_contacts  41188 non-null  int64
#  12  previous_outcome            41188 non-null  object
# ...

# %%
campaign=a[['client_id','number_contacts','contact_duration','previous_campaign_contacts','previous_outcome','campaign_outcome']]
campaign.head()
# Out:
#    client_id  number_contacts  contact_duration  previous_campaign_contacts  \
# 0          0                1               261                           0
# 1          1                1               149                           0
# 2          2                1               226                           0
# 3          3                1               151                           0
# 4          4                1               307                           0
#
#   previous_outcome campaign_outcome
# 0      nonexistent               no
# 1      nonexistent               no
# 2      nonexistent               no
# 3      nonexistent               no
# 4      nonexistent               no

# %%
economics=a[['client_id','cons_price_idx','euribor_three_months']]
economics.head()
# Out:
#    client_id  cons_price_idx  euribor_three_months
# 0          0          93.994                 4.857
# 1          1          93.994                 4.857
# 2          2          93.994                 4.857
# 3          3          93.994                 4.857
# 4          4          93.994                 4.857

# %%
c.to_csv('c.csv',index=False)#same name duh
campaign.to_csv('campaign.csv',index=False)#index=false ka matlab 0....10 or whatever bhag jaega
economics.to_csv('economics.csv',index=False)

# %%
c.to_excel('myclient.xlsx',index=False)
campaign.to_excel('mycampaign.xlsx',index=False)
economics.to_excel('economy.xlsx',index=False)

# %%
df=pd.read_excel('myclient.xlsx')
df.head()
# Out:
#    client_id  age        job  marital    education credit_default mortgage  \
# 0          0   56  housemaid  married     basic_4y             no       no
# 1          1   57   services  married  high_school        unknown       no
# 2          2   37   services  married  high_school             no      yes
# 3          3   40     admin_  married     basic_6y             no       no
# 4          4   56   services  married  high_school             no       no
#
#   month
# 0   may
# 1   may
# 2   may
# 3   may
# 4   may
