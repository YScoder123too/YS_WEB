# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("world_info.csv")
data.head()
# Out:
#            country                               region  population     area  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997   647500
# 1         Albania   EASTERN EUROPE                          3581655    28748
# 2         Algeria   NORTHERN AFRICA                        32930091  2381740
# 3  American Samoa   OCEANIA                                   57794      199
# 4         Andorra   WESTERN EUROPE                            71201      468
#
#   pop_density coatline_arearatio net_migration infant_maternity  \
# 0        48,0               0,00         23,06           163,07
# 1       124,6               1,26         -4,93            21,52
# 2        13,8               0,04         -0,39               31
# 3       290,4              58,29        -20,71             9,27
# 4       152,1               0,00           6,6             4,05
#
#    gdp_percapita literacy_percent phone_perperson arable_per crop_per  other  \
# ...

# %%
df=data.loc[:,['country','population','area','infant_maternity','gdp_percapita','literacy_percent','birthrate','deathrate']]

# %%
df.head()
# Out:
#            country  population     area infant_maternity  gdp_percapita  \
# 0     Afghanistan     31056997   647500           163,07          700.0
# 1         Albania      3581655    28748            21,52         4500.0
# 2         Algeria     32930091  2381740               31         6000.0
# 3  American Samoa        57794      199             9,27         8000.0
# 4         Andorra        71201      468             4,05        19000.0
#
#   literacy_percent birthrate deathrate
# 0             36,0      46,6     20,34
# 1             86,5     15,11      5,22
# 2             70,0     17,14      4,61
# 3             97,0     22,46      3,27
# 4            100,0      8,71      6,25

# %%
"""IMPO"""
df1=df.sort_values(by=['population'],ascending=False)

# %%
df1.head(10)
# Out:
#             country  population      area infant_maternity  gdp_percapita  \
# 42           China   1313973713   9596960            24,18         5000.0
# 94           India   1095351995   3287590            56,29         2900.0
# 214  United States    298444215   9631420              6,5        37800.0
# 95       Indonesia    245452739   1919440             35,6         3200.0
# 27          Brazil    188078227   8511965            29,61         7600.0
# 156       Pakistan    165803560    803940            72,44         2100.0
# 16      Bangladesh    147365352    144000             62,6         1900.0
# 169         Russia    142893540  17075200            15,39         8900.0
# 152        Nigeria    131859731    923768             98,8          900.0
# 103          Japan    127463611    377835             3,26        28200.0
#
#     literacy_percent birthrate deathrate
# 42              90,9     13,25      6,97
# 94              59,5     22,01      8,18
# ...

# %%
df2=df1.iloc[0:10]#TF is this
df2
# Out:
#             country  population      area infant_maternity  gdp_percapita  \
# 42           China   1313973713   9596960            24,18         5000.0
# 94           India   1095351995   3287590            56,29         2900.0
# 214  United States    298444215   9631420              6,5        37800.0
# 95       Indonesia    245452739   1919440             35,6         3200.0
# 27          Brazil    188078227   8511965            29,61         7600.0
# 156       Pakistan    165803560    803940            72,44         2100.0
# 16      Bangladesh    147365352    144000             62,6         1900.0
# 169         Russia    142893540  17075200            15,39         8900.0
# 152        Nigeria    131859731    923768             98,8          900.0
# 103          Japan    127463611    377835             3,26        28200.0
#
#     literacy_percent birthrate deathrate
# 42              90,9     13,25      6,97
# 94              59,5     22,01      8,18
# ...

# %%
plt.pie(df2['population'],labels=df2['country'])
plt.show()

# %%
plt.pie(df2['population'],labels=df2['country'],startangle=90)#china ko dekh==>90 degree anticlockwise
plt.show()

# %%
plt.pie(df2['population'],labels=df2['country'],startangle=90)#china ko dekh
plt.show()

# %%
plt.pie(df2['area'],labels=df2['country'])#china ko dekh
plt.show()
