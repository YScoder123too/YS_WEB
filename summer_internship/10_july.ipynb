# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
path= r"C:\Users\LENOVO\Downloads\student-alcohol-consumption.csv"
student_data=pd.read_csv(path)
student_data.head()
# Out:
#    Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0           0     GP   F   18     GT3       A     4     4           2
# 1           1     GP   F   17     GT3       T     1     1           1
# 2           2     GP   F   15     LE3       T     1     1           1
# 3           3     GP   F   15     GT3       T     4     2           1
# 4           4     GP   F   16     GT3       T     3     3           1
#
#    failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 0         0  ...     4    1    1      3        6   5   6   6     Urban
# 1         0  ...     3    1    1      3        4   5   5   6     Urban
# 2         3  ...     2    2    3      3       10   7   8  10     Urban
# 3         0  ...     2    1    1      5        2  15  14  15     Urban
# 4         0  ...     2    1    2      5        4   6  10  10     Urban
#
#       study_time
# 0   2 to 5 hours
# 1   2 to 5 hours
# 2   2 to 5 hours
# 3  5 to 10 hours
# 4   2 to 5 hours
#
# ...

# %%
sns.relplot(x='absences',y='G3',data=student_data,kind='scatter',color='blue')
plt.grid(linestyle='dashed',color='skyblue')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='absences',y='G3',data=student_data,kind='line',color='blue')
plt.grid(linestyle='dashed',color='skyblue')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='absences',y='G3',data=student_data,kind='scatter',color='blue',row='study_time')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='absences',y='G3',data=student_data,kind='scatter',color='blue',col='study_time')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='G1',y='G3',data=student_data,kind='scatter')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
mpg=pd.read_csv('mpg.csv')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='horsepower',y='mpg',data=mpg,kind='scatter',size='cylinders',hue='cylinders')#cylinders ek column hai
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='acceleration',y='mpg',data=mpg,kind='scatter',size='origin',hue='origin')#cylinders ek column hai#mast same naam likho
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='acceleration',y='mpg',data=mpg,kind='scatter',style='origin',hue='origin')#cylinders ek column hai#mast same naam likho
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='acceleration',y='mpg',data=mpg,kind='line',style='origin',hue='origin')#cylinders ek column hai#mast same naam likho
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='model_year',y='mpg',data=mpg,kind='line')#dark line mean hai,95% content is mean
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='model_year',y='mpg',data=mpg,kind='line',ci=None)#dark line mean hai,95% content is mean,light shadow bhag gayi
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='model_year',y='mpg',data=mpg,kind='line',ci='sd')#dark line mean hai,95% content is mean..ci=confidence interval
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='model_year',y='horsepower',data=mpg,kind='line',ci=None)#dark line mean hai,95% content is mean..ci=confidence interval
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='model_year',y='horsepower',data=mpg)
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 2nd dataframe

# %%
survey_data=pd.read_csv("young-people-survey-responses.csv")
survey_data.head()
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3           3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4           4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
# 3         5.0              2.0  most of the day       2.0  22.0       1.0
# 4         3.0              3.0  few hours a day       4.0  20.0       1.0
#
#    Gender Village - town
# 0  female        village
# ...

# %%
sns.catplot(x='Internet usage',data=survey_data,kind='count')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='Internet usage',data=survey_data,kind='count',height=4,aspect=2)
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(y='Internet usage',data=survey_data,kind='count',height=4,aspect=2)
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(y='Internet usage',data=survey_data,kind='count',col='Age')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
survey_data['Age category']
