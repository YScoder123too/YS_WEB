# %% [markdown]
# # SEABORN

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
height=[62,64,69,75,66,68,65,71,76,73]
weight=[120,136,148,175,137,165,154,172,200,187]
sns.scatterplot(x=height,y=weight)
plt.show()

# %%
gender=['Female','Female','Female','Female','Male','Male','Male','Male','Male','Male']
sns.countplot(x=gender)
plt.show()

# %%
df=pd.read_csv("masculinity.csv")
df.head()
# Out:
#    participant_id    age how_masculine how_important
# 0               1  18-34      Somewhat      Somewhat
# 1               2  18-34      Somewhat      Somewhat
# 2               3  18-34          Very      Not very
# 3               4  18-34          Very      Not very
# 4               5  18-34          Very          very

# %%
sns.countplot(x='how_masculine',data=df)
plt.show()

# %%
#hue ka matlab ek naya column add karna ho to,hue_order,load_data,palette mai ==>is dicttionary ko pass kar do:hue_colors

# %%
df1=pd.read_csv('student-alcohol-consumption.csv')
df1
# Out:
#      Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP   F   18     GT3       A     4     4           2
# 1             1     GP   F   17     GT3       T     1     1           1
# 2             2     GP   F   15     LE3       T     1     1           1
# 3             3     GP   F   15     GT3       T     4     2           1
# 4             4     GP   F   16     GT3       T     3     3           1
# ..          ...    ...  ..  ...     ...     ...   ...   ...         ...
# 390         390     MS   M   20     LE3       A     2     2           1
# 391         391     MS   M   17     LE3       T     3     1           2
# 392         392     MS   M   21     GT3       T     1     1           1
# 393         393     MS   M   18     LE3       T     3     2           3
# 394         394     MS   M   19     LE3       T     1     1           1
#
#      failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# ...

# %%
sns.countplot(x='study_time',data=df1)
plt.show()

# %%
sns.scatterplot(x='school',y='absences',hue='location',data=df1)#hue se legand ban jaega
plt.show()

# %%
df1['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
sns.countplot(x='age',data=df1)
plt.show()

# %%
sns.countplot(x='age',hue='sex',data=df1)
plt.show()

# %%
'''SCATTERPLOT VS RELATIONPLOT'''
# Out:
# 'SCATTERPLOT VS RELATIONPLOT'

# %%
sns.relplot(x='G1',y='absences',data=df1,kind='scatter',col='school',row='sex')#2 axis ke bich mai relation nikalna ho and 3rd column bhi chahiye to col
plt.show()#col and row dono kar sakte hai
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='G1',y='G3',kind='scatter',data=df)
plt.plot()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# []

# %%
sns.relplot(x='G1',y='G3',kind='scatter',data=df,col='schoolsup',col_order=['yes','no'])
plt.plot()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# []

# %%
sns.relplot(x='G1',y='G3',kind='scatter',data=df,col='schoolsup',col_order=['yes','no'],row='famsup',row_order=['yes','no'])
plt.plot()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# []
